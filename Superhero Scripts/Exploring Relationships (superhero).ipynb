# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
path = r'/Users/ethanahennes/Desktop/Unit 6/Data/'

# %%
df = pd.read_csv(os.path.join(path,'Super Hero Numerical Only.csv'),index_col = False)

# %%
matplotlib.__version__
# Out:
# '3.5.1'

# %%
# %matplotlib inline

# %%
df.shape
# Out:
# (8311, 8)

# %%
df.columns
# Out:
# Index(['Combat Level (1-100)', 'Ablity to Withstand Damage (1-100)', 'IQ',
#        'Intelligence (1-100)', 'Power Class (1-6)', 'Overall Power (1-100)',
#        'Speed (1-100)', 'Strength (1-100)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Combat Level (1-100)                  int64
# Ablity to Withstand Damage (1-100)    int64
# IQ                                    int64
# Intelligence (1-100)                  int64
# Power Class (1-6)                     int64
# Overall Power (1-100)                 int64
# Speed (1-100)                         int64
# Strength (1-100)                      int64
# dtype: object

# %%
df.head()
# Out:
#    Combat Level (1-100)  Ablity to Withstand Damage (1-100)   IQ  \
# 0                    80                                  35  140
# 1                    90                                 100  160
# 2                   100                                  45  140
# 3                    90                                  75  155
# 4                    40                                  15  110
#
#    Intelligence (1-100)  Power Class (1-6)  Overall Power (1-100)  \
# 0                    70                  3                     60
# 1                    80                  6                    100
# 2                    70                  3                     80
# 3                    80                  5                    100
# 4                    55                  1                     35
#
#    Speed (1-100)  Strength (1-100)
# 0             30                30
# 1            100               100
# 2             50                50
# ...

# %%
df.isnull().sum()
# Out:
# Combat Level (1-100)                  0
# Ablity to Withstand Damage (1-100)    0
# IQ                                    0
# Intelligence (1-100)                  0
# Power Class (1-6)                     0
# Overall Power (1-100)                 0
# Speed (1-100)                         0
# Strength (1-100)                      0
# dtype: int64

# %%
for col in df.columns.tolist():
      weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df[weird]) > 0:
        print (col)

# %%
df.corr()
# Out:
#                                     Combat Level (1-100)  \
# Combat Level (1-100)                            1.000000
# Ablity to Withstand Damage (1-100)              0.447991
# IQ                                              0.454610
# Intelligence (1-100)                            0.452818
# Power Class (1-6)                               0.452134
# Overall Power (1-100)                           0.357509
# Speed (1-100)                                   0.469845
# Strength (1-100)                                0.428110
#
#                                     Ablity to Withstand Damage (1-100)  \
# Combat Level (1-100)                                          0.447991
# Ablity to Withstand Damage (1-100)                            1.000000
# IQ                                                            0.543614
# Intelligence (1-100)                                          0.544643
# Power Class (1-6)                                             0.894794
# ...

# %%
plt.matshow(df.corr())
plt.show()

# %%
plt.matshow(df.corr())
plt.savefig("out.png")

# %%
cwd = os.getcwd()
cwd
# Out:
# '/Users/ethanahennes/Desktop/Unit 6/Scripts'

# %%
f = plt.figure(figsize=(9,9)) 
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.shape[1]), df.columns, fontsize=12, rotation=45) 
plt.yticks(range(df.shape[1]), df.columns, fontsize=12) 
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
df.columns
# Out:
# Index(['Combat Level (1-100)', 'Ablity to Withstand Damage (1-100)', 'IQ',
#        'Intelligence (1-100)', 'Power Class (1-6)', 'Overall Power (1-100)',
#        'Speed (1-100)', 'Strength (1-100)'],
#       dtype='object')

# %%
sub = df[['Combat Level (1-100)', 'Ablity to Withstand Damage (1-100)', 'IQ',
       'Intelligence (1-100)', 'Power Class (1-6)', 'Overall Power (1-100)',
       'Speed (1-100)', 'Strength (1-100)']]

# %%
sub
# Out:
#       Combat Level (1-100)  Ablity to Withstand Damage (1-100)   IQ  \
# 0                       80                                  35  140
# 1                       90                                 100  160
# 2                      100                                  45  140
# 3                       90                                  75  155
# 4                       40                                  15  110
# ...                    ...                                 ...  ...
# 8306                    85                                  40  180
# 8307                    70                                  95  180
# 8308                    75                                  60  130
# 8309                   100                                 100  200
# 8310                    80                                   1  150
#
#       Intelligence (1-100)  Power Class (1-6)  Overall Power (1-100)  \
# 0                       70                  3                     60
# ...

# %%
f,ax = plt.subplots(figsize=(10,10))

corr = sns.heatmap(sub.corr(), annot = True, ax = ax)

# %%
sns.savefig("in.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 sns.savefig("in.png")
#
# AttributeError: module 'seaborn' has no attribute 'savefig'

# %%
sns.lmplot(x = 'Power Class (1-6)', y = 'Strength (1-100)', data = df)

# %%
sub_2 = sub[['Power Class (1-6)', 'Strength (1-100)', 'Ablity to Withstand Damage (1-100)', 'Speed (1-100)']]

# %%
g = sns.pairplot(sub_2)

# %%
sns.histplot(df['Power Class (1-6)'], bins = 6, kde = True)
# Out:
# <AxesSubplot:xlabel='Power Class (1-6)', ylabel='Count'>

# %%
sns.histplot(df['Power Class (1-6)'], bins = 6, kde = True)
